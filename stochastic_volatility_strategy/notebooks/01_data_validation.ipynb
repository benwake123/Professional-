# %% [markdown]
# # 01 — Data Validation
#
# Quick smoke test for the data layer. Loads the public data pack, asserts every validator passes, and shows a head() of each table.
#
# Production assertions live in `tests/test_data_validation.py`, `tests/test_no_lookahead.py`, and `tests/test_real_data.py`.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.config import load_config, resolve_project_paths
from src.data_loader import load_all_market_data
from src.data_validation import validate_all_data

config = load_config(ROOT / 'config.json')
paths = resolve_project_paths(config, project_root=ROOT)
bundle = load_all_market_data(paths)
validate_all_data(bundle)
print('validation passed')
bundle.underlying.head()
