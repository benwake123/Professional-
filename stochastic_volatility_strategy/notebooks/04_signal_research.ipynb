# %% [markdown]
# # 04 — Signal Research
#
# Inspect the VRP z-score distribution and the regime classifier output produced by the backtest. Reads `results/trade_decisions.csv`.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import pandas as pd
decisions = pd.read_csv(ROOT / 'results' / 'trade_decisions.csv')
decisions.head()
